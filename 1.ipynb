# %%
import pandas as pd

# %%
df1=pd.read_excel("VendorProducts.xlsx",sheet_name="Items")

df2=pd.read_excel("VendorProducts.xlsx",sheet_name="Collections")

# %%
df1.columns
# Out:
# Index(['Picture', 'Id', 'Name', 'Secondary Name', 'Barcode', 'Code', 'Price',
#        'Description', 'Secondary Description', 'Sub Description',
#        'Secondary Sub Description', 'Menu', 'Brand', 'Secondary Brand',
#        'Has Collections'],
#       dtype='str')

# %%
df3=df1["Price"]

# %%
df4=list[df3]

# %%
df4
# Out:
# list[0         25,000د.ع
# 1        300,000د.ع
# 2         30,000د.ع
# 3             00د.ع
# 4         15,000د.ع
#             ...
# 24697     16,500د.ع
# 24698     12,000د.ع
# 24699     10,500د.ع
# 24700     15,000د.ع
# 24701     22,500د.ع
# Name: Price, Length: 24702, dtype: str]

# %%
for i in df3:
    x=i.replace("د.ع","")
    y=int(x.replace(",",""))
    print(pd.Series(y))
# Out:
# 0    25000
# dtype: int64
# 0    300000
# dtype: int64
# 0    30000
# dtype: int64
# 0    0
# dtype: int64
# 0    15000
# dtype: int64
# 0    15000
# dtype: int64
# 0    18000
# dtype: int64
# 0    15000
# dtype: int64
# 0    7750
# dtype: int64
# 0    15500
# dtype: int64
# 0    65000
# dtype: int64
# 0    3500
# dtype: int64
# 0    19000
# dtype: int64
# 0    38000
# dtype: int64
# 0    15500
# dtype: int64
# 0    8000
# dtype: int64
# 0    115500
# dtype: int64
# 0    6500
# dtype: int64
# 0    30000
# dtype: int64
# 0    20000
# dtype: int64
# 0    4000
# dtype: int64
# 0    30000
# dtype: int64
# 0    4000
# dtype: int64
# 0    32000
# dtype: int64
# 0    4000
# dtype: int64
# 0    30000
# dtype: int64
# 0    45000
# dtype: int64
# 0    37000
# dtype: int64
# 0    30000
# dtype: int64
# 0    10000
# dtype: int64
# 0    3500
# dtype: int64
# 0    3500
# dtype: int64
# 0    45000
# dtype: int64
# 0    45000
# dtype: int64
# 0    15000
# dtype: int64
# 0    50000
# dtype: int64
# ...

# %%
df1[["Picture","Id","Price"]]
# Out:
#                                                  Picture      Id       Price
# 0      https://www.storeakmedia.com/storeak-erp/Store...  390188   25,000د.ع
# 1      https://www.storeakmedia.com/storeak-erp/Store...  390187  300,000د.ع
# 2      https://www.storeakmedia.com/storeak-erp/Store...  390186   30,000د.ع
# 3      https://www.storeakmedia.com/storeak-erp/Store...  390185       00د.ع
# 4      https://www.storeakmedia.com/storeak-erp/Store...  390177   15,000د.ع
# ...                                                  ...     ...         ...
# 24697  https://www.storeakmedia.com/storeak-erp/Store...  315019   16,500د.ع
# 24698  https://www.storeakmedia.com/storeak-erp/Store...  315018   12,000د.ع
# 24699  https://www.storeakmedia.com/storeak-erp/Store...  314993   10,500د.ع
# 24700  https://www.storeakmedia.com/storeak-erp/Store...  314992   15,000د.ع
# 24701  https://www.storeakmedia.com/storeak-erp/Store...  314991   22,500د.ع
#
# [24702 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24702 entries, 0 to 24701
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Picture                    24300 non-null  str
#  1   Id                         24702 non-null  int64
#  2   Name                       24702 non-null  str
#  3   Secondary Name             24702 non-null  str
#  4   Barcode                    22041 non-null  str
#  5   Code                       21993 non-null  str
#  6   Price                      24702 non-null  str
#  7   Description                24645 non-null  str
#  8   Secondary Description      24644 non-null  str
#  9   Sub Description            24601 non-null  str
#  10  Secondary Sub Description  4 non-null      str
#  11  Menu                       24699 non-null  str
#  12  Brand                      24699 non-null  str
#  13  Secondary Brand            24696 non-null  str
# ...

# %%
df1.describe()
# Out:
#                   Id
# count   24702.000000
# mean   330583.440936
# std     12701.598678
# min    314991.000000
# 25%    321257.250000
# 50%    327496.500000
# 75%    334544.750000
# max    390188.000000

# %%
dic={"name":["umar","farooq","ali"],"age":[20,21,23],"class":["BSSE","BSCS","BSIT"]}
dfs=pd.DataFrame(dic)
dfg=dfs.to_csv("newdata.csv",index=False)

# %%
dfh=pd.read_csv("newdata.csv")

# %%
currentnumber=len(dfh["name"])
currentnumber
# Out:
# 3
