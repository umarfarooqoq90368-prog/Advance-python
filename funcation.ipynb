# %%
import pandas as pd

# %%
df1=pd.read_excel("VendorProducts.xlsx",sheet_name="Items")

df2=pd.read_excel("VendorProducts.xlsx",sheet_name="Collections")

# %%
def cleanprice(listofprice,iteam):
    cleandata=[]
    for i in range (len(listofprice)):
       listofprice[i]=listofprice[i].replace(iteam,"")
       iteam.append(listofprice[i])
       return cleanprice

# %%
class bike:
    def __init__(self,firstname):
        self.firstname=firstname
    def lastname(self,lastname):
        self.firstname=self.firstname+""+lastname
    def name(self):
        self.lastname=self.firstname
    def number(self):
        print("2750")

# %%
b=bike("cd")
b.lastname("70")
b.number()
# Out:
# 2750

# %% [markdown]
# inhertance

# %%
class paclass:
    def parent(self):
        print("this my parent")
class chclass(paclass):
    def child(self):
        print("this my child")

# %%
chiled=chclass()
chiled.parent()
chiled.child()
# Out:
# this my parent
# this my child
