# %%
import pandas as pd

# %%
Studentdata = {"StudentId":["10001","10002","10003"],"StudentName":["Ahmad","Ali","yth"],"StudentClass":["1","2","3"],"Subjects":[["Math","English","Science"],["Math","Chemistry","Science"],["islamicStudies","English","Physics"]]}
sdf=pd.DataFrame(Studentdata)
sdf.to_csv("collage.csv")

# %%
# Out:
#   StudentId StudentName StudentClass                            Subjects
# 0     10001       Ahmad            1            [Math, English, Science]
# 1     10002         Ali            2          [Math, Chemistry, Science]
# 2     10003         yth            3  [islamicStudies, English, Physics]
