# %%
import pandas as pd

# %%
Studentdata = {"StudentId":["101","102","103"],"StudentName":["umar","farooq","ali"],"StudentClass":["1","2","3"],"Subjects":[["Math","English","Science"],["Math","Chemistry","Science"],["islamicStudies","English","Physics"]]}
sdf=pd.DataFrame(Studentdata)
sdf.to_csv("collage.csv",index=False)

# %%
while True:
    choice=input("Enter your choice:\n"
                     "1: student registration\n"
                     "2: student information fetch\n"
                     "3: student information update\n"
                     "4: exit\n")
    if choice=="1":
        sdf=pd.read_csv("collage.csv")
        student_id=input("Enter student ID:\n")
        student_name=input("Enter student name:\n")
        student_class=input("Enter student class:\n")
        subjects=input(["Math","Chemistry","Science"])
        if student_id in Studentdata["StudentId"]:
            print("your already registered")
        else:
              Studentdata["StudentId"].append(student_id)
              Studentdata["StudentName"].append(student_name)
              Studentdata["StudentClass"].append(student_class)
              Studentdata["Subjects"].append(subjects)
              sdf=pd.DataFrame(Studentdata)
              sdf=df.to_csv("collage.csv",index=False)
    elif choice=="2":
        print("Student Information fetch")

    elif choice=="3":
        print("Student Information update")
    elif choice=="4":
        break
# Out:
# your already registered

# %%
sdf
# Out:
#    StudentId StudentName  StudentClass  \
# 0        101        umar             1
# 1        102      farooq             2
# 2        103         ali             3
#
#                                    Subjects
# 0            ['Math', 'English', 'Science']
# 1          ['Math', 'Chemistry', 'Science']
# 2  ['islamicStudies', 'English', 'Physics']
